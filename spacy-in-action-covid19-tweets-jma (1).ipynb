# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import random

# %%
df= pd.read_csv("../input/covid19-tweets/covid19_tweets.csv")
random.seed(22)
text = df.text[random.sample(range(1,50),5)]
text
# Out:
# 9     POPE AS GOD - Prophet Sadhu Sundar Selvaraj. W...
# 16    July 25 #COVID19 update\n#TamilNadu - 6988\nDi...
# 2     @diane3443 @wdunlap @realDonaldTrump Trump nev...
# 40    #PlayYourPart in the fight against #COVID19 . ...
# 29    @ratasjuri TAX Reform\n\nTax-free minimum:\nFo...
# Name: text, dtype: object

# %%
df.shape
# Out:
# (179108, 13)

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
text1 = str(text)
doc = nlp(text1)

# %%
df = pd.DataFrame()

for i, token in enumerate(doc):
    df.loc[i, 'text'] = token.text
    df.loc[i, 'pos'] = token.pos_
    df.loc[i, 'dep'] = token.dep_

# %%
df.head(15)
# Out:
#         text    pos       dep
# 0          9    NUM    nummod
# 1             SPACE
# 2       POPE  PROPN  compound
# 3         AS    ADP      ROOT
# 4        GOD  PROPN  compound
# 5          -  PUNCT     punct
# 6    Prophet  PROPN  compound
# 7      Sadhu  PROPN  compound
# 8     Sundar  PROPN  compound
# 9   Selvaraj  PROPN      dobj
# 10         .  PUNCT     punct
# 11         W   NOUN      ROOT
# 12       ...  PUNCT     punct
# 13        \n  SPACE
# 14        16    NUM      ROOT

# %%
df1 = pd.DataFrame()
for i,token in enumerate(doc):
    df1.loc[i,'text'] = token.text

# %%
print(df1.head(15))
# Out:
#         text
# 0          9
# 1
# 2       POPE
# 3         AS
# 4        GOD
# 5          -
# 6    Prophet
# 7      Sadhu
# 8     Sundar
# 9   Selvaraj
# 10         .
# 11         W
# 12       ...
# 13        \n
# 14        16

# %%
df3 = pd.DataFrame()
for i,token in enumerate(doc):
    df3.loc[i,'text'] = token.text
    df3.loc[i,'lemma_'] = token.lemma_
    df3.loc[i,'pos_'] = token.pos_
    df3.loc[i,'tag_'] = token.tag_
    df3.loc[i,'dep_'] = token.dep_
    df3.loc[i,'shape_'] = token.shape_
    df3.loc[i,'is_alpha'] = token.is_alpha
    df3.loc[i,'is_stop'] = token.is_stop
df3.head(15)
# Out:
#         text    lemma_   pos_  tag_      dep_ shape_ is_alpha is_stop
# 0          9         9    NUM    CD    nummod      d    False   False
# 1                       SPACE   _SP                     False   False
# 2       POPE      POPE  PROPN   NNP  compound   XXXX     True   False
# 3         AS        as    ADP    IN      ROOT     XX     True    True
# 4        GOD       GOD  PROPN   NNP  compound    XXX     True   False
# 5          -         -  PUNCT  HYPH     punct      -    False   False
# 6    Prophet   Prophet  PROPN   NNP  compound  Xxxxx     True   False
# 7      Sadhu     Sadhu  PROPN   NNP  compound  Xxxxx     True   False
# 8     Sundar    Sundar  PROPN   NNP  compound  Xxxxx     True   False
# 9   Selvaraj  Selvaraj  PROPN   NNP      dobj  Xxxxx     True   False
# 10         .         .  PUNCT     .     punct      .    False   False
# 11         W         w   NOUN    NN      ROOT      X     True   False
# 12       ...       ...  PUNCT     :     punct    ...    False   False
# 13        \n        \n  SPACE   _SP               \n    False   False
# 14        16        16    NUM    CD      ROOT     dd    False   False

# %%
spacy.displacy.render(doc, style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      POPE AS GOD - Prophet
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sadhu Sundar Selvaraj
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . W...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     16
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#     July 25 #
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  update\n#TamilNadu -
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6988\nDi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      @diane3443 @wdunlap @realDonaldTrump Trump nev...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     40
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#     #PlayYourPart in the fight against #
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  . ...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     29
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#     @ratasjuri TAX Reform\n\nTax-free minimum:\nFo...
# Name: text, dtype: object</div></span>

# %%
spacy.displacy.render(doc, style='dep',jupyter=True,options = {'compact':60})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4ce2d1c528144d34a6f21802a9446032-0" class="displacy" width="7250" height="512.0" direction="ltr" style="max-width: none; height: 512.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">9</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">    </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">POPE</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">AS</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">GOD -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">Prophet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">Sadhu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Sundar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Selvaraj.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">W...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">16</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">   </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">July</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">25 #</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">COVID19</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">update\n#TamilNadu -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">6988\nDi...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">2</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">    </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">@diane3443</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">@wdunlap</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">@realDonaldTrump</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">Trump</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">nev...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">40</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">   #</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">PlayYourPart</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="4550">in</tspan>
#     <tspan class="displ

# %%
df2 = pd.DataFrame()

for i, ent in enumerate(doc):
    df2.loc[i, 'text'] = ent.text
    df2.loc[i, 'pos'] = ent.pos_
    df2.loc[i, 'dep'] = ent.dep_

# %%
df2.head(15)
# Out:
#         text    pos       dep
# 0          9    NUM    nummod
# 1             SPACE
# 2       POPE  PROPN  compound
# 3         AS    ADP      ROOT
# 4        GOD  PROPN  compound
# 5          -  PUNCT     punct
# 6    Prophet  PROPN  compound
# 7      Sadhu  PROPN  compound
# 8     Sundar  PROPN  compound
# 9   Selvaraj  PROPN      dobj
# 10         .  PUNCT     punct
# 11         W   NOUN      ROOT
# 12       ...  PUNCT     punct
# 13        \n  SPACE
# 14        16    NUM      ROOT

# %%
df3 = pd.DataFrame()
for i,token in enumerate(doc):
    df3.loc[i,'text'] = token.text
    df3.loc[i,'has_vector'] = token.has_vector
    df3.loc[i,'vector_norm'] = token.vector_norm
    df3.loc[i,'is_oov'] = token.is_oov

# %%
df3.head(15)
# Out:
#         text has_vector  vector_norm is_oov
# 0          9       True    18.760708   True
# 1                  True    17.494509   True
# 2       POPE       True    18.300705   True
# 3         AS       True    18.616552   True
# 4        GOD       True    20.097767   True
# 5          -       True    20.369368   True
# 6    Prophet       True    18.507166   True
# 7      Sadhu       True    18.799604   True
# 8     Sundar       True    20.619337   True
# 9   Selvaraj       True    18.560116   True
# 10         .       True    16.932163   True
# 11         W       True    15.722784   True
# 12       ...       True    18.806469   True
# 13        \n       True    19.584547   True
# 14        16       True    20.395735   True

# %%
for word in doc:
    lexeme = doc.vocab[word.text]
    print(lexeme.text, lexeme.orth, lexeme.shape_, lexeme.prefix_, lexeme.suffix_,
          lexeme.is_alpha, lexeme.is_digit, lexeme.is_title, lexeme.lang_)
# Out:
# 9 1819085394523955522 d 9 9 False True False en
#      3518396686757337811            False False False en
# POPE 786391748380289908 XXXX P OPE True False False en
# AS 6549161203909013836 XX A AS True False False en
# GOD 15330477398270548641 XXX G GOD True False False en
# - 9153284864653046197 - - - False False False en
# Prophet 9415357610043601313 Xxxxx P het True False True en
# Sadhu 18327404551211308297 Xxxxx S dhu True False True en
# Sundar 16871648220742789574 Xxxxx S dar True False True en
# Selvaraj 14479898519934791538 Xxxxx S raj True False True en
# . 12646065887601541794 . . . False False False en
# W 14825646868312541310 X W W True False True en
# ... 10875615029400813363 ... . ... False False False en
#
#  962983613142996970
#
#
#  False False False en
# 16 4206877449096176963 dd 1 16 False True False en
#     6718839663412986256           False False False en
# July 8720688718313716327 Xxxx J uly True False True en
# 25 4522981160172931067 dd 2 25 False True False en
# # 8663801465970268676 # # # False False False en
# COVID19 8003531699212419486 XXXXdd C D19 False False False en
# update\n#TamilNadu 17564812649417825310 xxxx\x#XxxxxXxxx u adu False False False en
# - 9153284864653046197 - - - False False False en
# 6988\nDi 15299053573099819962 dddd\xXx 6 nDi False False False en
# ... 10875615029400813363 ... . ... False False False en
#
#  962983613142996970
#
#
#  False False False en
# 2 15180167692696242062 d 2 2 False True False en
#      3518396686757337811            False False False en
# @diane3443 18267771993092549987 @xxxxdddd @ 443 False False False en
# @wdunlap 6800103978732657181 @xxxx @ lap False False False en
# @realDonaldTrump 5952503656322695203 @xxxxXxxxxXxxxx @ ump False False False en
# Trump 1134333841961332695 Xxxxx T ump True False True en
# nev 2458179410973125679 xxx n nev True False False en
# ... 10875615029400813363 ... . ... False False False en
#
#  962983613142996970
#
#
#  False False False en
# 40 5087266072664039774 dd 4 40 False True False en
#     6718839663412986256           False False False en
# # 8663801465970268676 # # # False False False en
# PlayYourPart 9497958204182898634 XxxxXxxxXxxx P art True False False en
# in 3002984154512732771 xx i in True False False en
# the 7425985699627899538 xxx t the True False False en
# fight 15486772212226780222 xxxx f ght True False False en
# against 16640565335581469180 xxxx a nst True False False en
# # 8663801465970268676 # # # False False False en
# COVID19 8003531699212419486 XXXXdd C D19 False False False en
# . 12646065887601541794 . . . False False False en
# ... 10875615029400813363 ... . ... False False False en
#
#  962983613142996970
#
#
#  False False False en
# 29 3184100032543944061 dd 2 29 False True False en
#     6718839663412986256           False False False en
# @ratasjuri 5142935849249835607 @xxxx @ uri False False False en
# TAX 16030703925199487181 XXX T TAX True False False en
# Reform\n\nTax 17111579987924534046 Xxxxx\x\xXxx R Tax False False False en
# - 9153284864653046197 - - - False False False en
# free 17712913731469760764 xxxx f ree True False False en
# minimum:\nFo 18001968064709295214 xxxx:\xXx m nFo False False False en
# ... 10875615029400813363 ... . ... False False False en
#
#  962983613142996970
#
#
#  False False False en
# Name 16534757564620902542 Xxxx N ame True False True en
# : 11532473245541075862 : : : False False False en
# text 15099781594404091470 xxxx t ext True False False en
# , 2593208677638477497 , , , False False False en
# dtype 14573301518653548249 xxxx d ype True False False en
# : 11532473245541075862 : : : False False False en
# object 17242611361085688134 xxxx o ect True False False en

# %%
from spacy import displacy
displacy.render(doc, style='dep', jupyter=True, options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="96d7f763c90d4e6ab026c56e3b455145-0" class="displacy" width="4370" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">9</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">    </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">POPE</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">AS</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">GOD -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">Prophet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">Sadhu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">Sundar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Selvaraj.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">W...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">16</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">   </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">July</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">25 #</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">COVID19</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">update\n#TamilNadu -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">6988\nDi...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">2</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">    </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">@diane3443</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">@wdunlap</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">@realDonaldTrump</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">Trump</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">nev...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">40</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">   #</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">PlayYourPart</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">in</tspan>
#     <tspan class="displacy-tag"
